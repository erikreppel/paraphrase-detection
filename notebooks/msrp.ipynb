# %%
import numpy as np
import pandas as pd

# %%
TEST_FP = './data/msr_paraphrase_test.txt'
TRAIN_FP = './data/msr_paraphrase_train.txt'

# %%
train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-269eb77b41b7> in <module>()
# ----> 1 train
#
# NameError: name 'train' is not defined

# %%
df
# Out:
#        Sentence ID                                             String  \
# 0           702876  Amrozi accused his brother, whom he called "th...
# 1           702977  Referring to him as only "the witness", Amrozi...
# 2          2108705  Yucaipa owned Dominick's before selling the ch...
# 3          2108831  Yucaipa bought Dominick's in 1995 for $693 mil...
# 4          1330381  They had published an advertisement on the Int...
# 5          1330521  On June 10, the ship's owners had published an...
# 6          3344667  Around 0335 GMT, Tab shares were up 19 cents, ...
# 7          3344648  Tab shares jumped 20 cents, or 4.6%, to set a ...
# 8          1236820  The stock rose $2.11, or about 11 percent, to ...
# 9          1236712  PG&E Corp. shares jumped $1.63 or 8 percent to...
# 10          738533  Revenue in the first quarter of the year dropp...
# 11          737951  With the scandal hanging over Stewart's compan...
# ...

# %%
sentences = df['String']

# %%
pairs = zip(df.iloc[1::2]['String'], df.iloc[::2]['String'])
p1, p2 = df.iloc[1::2]['String'], df.iloc[::2]['String']

# %%
words1 = [x for x in df.iloc[1::2]['String']]
words2 = [x for x in df.iloc[::2]['String']]

# %%
all_words = words1 + words2

# %%
from keras.preprocessing.text import text_to_word_sequence, one_hot

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer(lowercase=True, stop_words='english',  max_df=1.0, min_df=1, max_features=None,  binary=True)

# %%
p1_vec = vectorizer.fit_transform(p1).toarray()
p2_vec = vectorizer.fit_transform(p2).toarray()

# %%
def
